# %% [markdown]
# # Предсказываем стоимость мед страховки

# %% [markdown]
# ## Загужаем необходимые библиотеки

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Загружаем данные
#
# Собраны данные:
# - age: возраст
# - sex: пол
# - bmi: индекс массы тела
# - children: количество детей, охваченных медицинским страхованием / количество иждивенцев
# - smoker: курение
# - region: регион (northeast, southeast, southwest, northwest).
# - charges: индивидуальные медицинские расходы (его и хотим предсказать)

# %%
# Загружаем данные из файла insurance.csv в переменную df
df = pd.read_csv('insurance.csv', sep=',')

# %%
# Посмотрим первые 5 строк
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Смотрим статистику, что нет пропусков и отсуствующих значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Посмотрим статистику
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Преобразуем строковые данные

# %%
# Заменяем пол и курение на числа
df['sex']=df['sex'].map({'male':1, 'female':0})
df['smoker']=df['smoker'].map({'yes':1,'no':0})

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Заменяем регион на набор отдельных колонок (region_southwest, region_southeast и тд)
df = pd.get_dummies(df, columns=['region'])
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    0  27.900         0       1  16884.92400                 0
# 1   18    1  33.770         1       0   1725.55230                 0
# 2   28    1  33.000         3       0   4449.46200                 0
# 3   33    1  22.705         0       0  21984.47061                 0
# 4   32    1  28.880         0       0   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %% [markdown]
# ## Формируем признаки и целевую переменную

# %%
# Сформируем признаки
X = df[['age', 'sex',	'bmi',	'children',	'smoker',	'region_northeast',	'region_northwest',	'region_southeast',	'region_southwest']]
X
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 0      19    0  27.900         0       1                 0                 0
# 1      18    1  33.770         1       0                 0                 0
# 2      28    1  33.000         3       0                 0                 0
# 3      33    1  22.705         0       0                 0                 1
# 4      32    1  28.880         0       0                 0                 1
# ...   ...  ...     ...       ...     ...               ...               ...
# 1333   50    1  30.970         3       0                 0                 1
# 1334   18    0  31.920         0       0                 1                 0
# 1335   18    0  36.850         0       0                 0                 0
# 1336   21    0  25.800         0       0                 0                 0
# 1337   61    0  29.070         0       1                 0                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 9 columns]

# %%
# Сформируем целевую переменную
y = df[['charges']]
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## Разделяем данные на тестовую выборку и для обучения

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 1337   61    0  29.070         0       1                 0                 1
# 611    38    0  34.800         2       0                 0                 0
# 170    63    1  41.470         0       0                 0                 0
# 408    38    1  21.120         3       0                 0                 0
# 506    22    1  31.350         1       0                 0                 1
# ...   ...  ...     ...       ...     ...               ...               ...
# 659    57    0  28.785         4       0                 1                 0
# 509    57    0  28.700         0       0                 0                 0
# 326    27    0  23.210         1       0                 0                 0
# 177    54    1  29.200         1       0                 0                 0
# 987    45    0  27.645         1       0                 0                 1
#
#       region_southeast  region_southwest
# 1337                 0                 0
# 611                  0                 1
# 170                  1                 0
# 408                  1                 0
# 506                  0                 0
# ...                ...               ...
# 659                  0                 0
# 509                  0                 1
# 326                  1                 0
# 177                  0                 1
# 987                  0                 0
#
# [1070 rows x 9 columns]

# %%
X_test
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 185    36    1  41.895         3       1                 1                 0
# 321    26    0  29.640         4       0                 1                 0
# 1056   48    0  28.900         0       0                 0                 0
# 485    31    0  31.065         0       0                 1                 0
# 991    38    0  27.835         2       0                 1                 0
# ...   ...  ...     ...       ...     ...               ...               ...
# 1027   23    1  18.715         0       0                 0                 1
# 1249   32    1  33.630         1       1                 1                 0
# 472    19    0  29.800         0       0                 0                 0
# 644    43    1  35.310         2       0                 0                 0
# 774    41    1  34.200         2       0                 0                 1
#
#       region_southeast  region_southwest
# 185                  0                 0
# 321                  0                 0
# 1056                 0                 1
# 485                  0                 0
# 991                  0                 0
# ...                ...               ...
# 1027                 0                 0
# 1249                 0                 0
# 472                  0                 1
# 644                  1                 0
# 774                  0                 0
#
# [268 rows x 9 columns]

# %% [markdown]
# ## Создаем и обучаем модель линейной регресии

# %%
# Создаем и обучаем модель линейной регресии
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Посмотрим коэффициенты
lr.coef_
# Out:
# array([[  260.34380993,  -111.02236521,   323.35338474,   422.18634755,
#         23641.91599999,   576.74130781,   102.39153277,  -370.61949507,
#          -308.51334552]])

# %% [markdown]
# ## Получаем предсказание и оцениваем качество

# %%
# Получаем предсказание
lr.predict(X_test)
# Out:
# array([[36075.24384312],
#        [ 6400.40272657],
#        [ 9314.68499685],
#        [ 6474.15495928],
#        [ 8096.50289121],
#        [14443.60170144],
#        [10124.16178524],
#        [ 3328.15951533],
#        [16352.95765484],
#        [ 3808.7756561 ],
#        [11864.36932248],
#        [39308.90581844],
#        [ 4128.51642167],
#        [ 4422.12622617],
#        [ 8370.22671863],
#        [ 2873.12733281],
#        [13389.37954848],
#        [ 7644.15425209],
#        [28484.88342686],
#        [10992.44426321],
#        [ 9955.24489352],
#        [ 5190.36928798],
#        [12107.53090593],
#        [ 9058.78955734],
#        [ 6919.09214638],
#        [33598.22284557],
#        [11061.33820503],
#        [ 3982.15723828],
#        [23078.48613865],
#        [31334.84931845],
#        [ 4539.30296474],
#        [ 2964.77898671],
#        [38806.47882651],
#        [ 7397.11216725],
#        [13076.21425369],
#        [ 2160.80067763],
#        [  272.39285472],
#        [37544.55953992],
#        [10396.91379615],
#        [ 3693.67306217],
#        [ 4762.95549637],
#        [ 3661.9711785 ],
#        [ 9458.34263308],
#        [ 2763.69767849],
#        [ 9821.52211219],
#        [ 1798.886842  ],
#        [ 8879.22719796],
#        [ 6661.39454653],
#        [12726.22760284],
#        [ 9652.63503147],
#        [15550.55104338],
#        [12353.42233234],
#        [ 8502.41764332],
#        [39826.71839914],
#        [ 1953.01570055],
#        [ 5902.4171701 ],
#        [37186.78935362],
#        [38509.67690999],
#        [ 5317.50513886],
#        [25173.81315837],
#        [ 7058.87274661],
#        [ 9781.98608516],
#        [ 4951.34664159],
#        [40068.81161164],
#        [29216.93883198],
#        [13909.30965671],
#        [33782.8900214 ],
#        [14790.20043288],
#        [ 7084.86417469],
#        [10693.83738816],
#        [14817.00879814],
#        [ 5949.90708569],
#        [ 9967.04639109],
#        [12415.30038691],
#        [11136.15536561],
#        [10151.69612879],
#        [28243.10725112],
#        [ 8967.048681  ],
#        [28297.76445009],
#        [11725.77216749],
#        [ 6416.7980449 ],
#        [12656.02069878],
#        [27083.59689397],
#        [ 5697.81295563],
#        [34535.29928144],
#        [  982.97994991],
#        [10058.72947226],
#        [ 6062.53725212],
#        [ 2777.91542518],
#        [11600.83250097],
#        [ 1154.41542248],
#        [  105.08394636],
#        [11381.70488892],
#        [12602.58830446],
#        [30568.47181763],
#        [25670.02906341],
#        [13631.81847701],
#        [ 5070.14121187],
#        [ 5588.82274765],
#        [11698.42013544],
#        [36130.42574626],
#        [31008.0647798 ],
#        [ 9430.01000096],
#        [11295.82179671],
#        [10616.72385792],
#        [13465.53450394],
#        [13574.65274694],
#        [ 6880.45992809],
#        [ 8712.15399122],
#        [13227.21263881],
#        [ 6154.88732588],
#        [ 5642.68547099],
#        [14972.12975238],
#        [-1628.09863186],
#        [16691.86569845],
#        [12621.60244895],
#        [ 8305.80949258],
#        [25212.61847793],
#        [ 5105.57528272],
#        [12036.93614983],
#        [13381.58757703],
#        [10674.92785066],
#        [ 3811.65896604],
#        [12091.91163266],
#        [ 1641.13709351],
#        [ 3190.13281207],
#        [28311.12453594],
#        [25200.67515521],
#        [ 2211.78596121],
#        [12240.87187065],
#        [31414.22975522],
#        [ 7458.28188671],
#        [13172.80995552],
#        [14647.79305552],
#        [28818.95965306],
#        [ 6613.12418084],
#        [ -675.8229138 ],
#        [35266.99232214],
#        [ 3528.22828343],
#        [ 9292.69482686],
#        [12698.86407517],
#        [ -314.88252504],
#        [ 5612.00279864],
#        [ 7595.60399577],
#        [12689.96854534],
#        [ 8374.57821986],
#        [ -187.38196197],
#        [31516.9801834 ],
#        [ 2055.73255505],
#        [10756.90532372],
#        [10350.30647463]])

# %%
# Oцениваем качество, при помощи метода mean_squared_error для тестовой выборки ($ 5 957, 60)
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 35493044.35785834

# %%
# Oцениваем качество, при помощи метода mean_squared_error для выборки обучения ($ 6 066, 86)
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 36806899.035589255

# %% [markdown]
# ## Делаем предсказание для одного человека

# %%
# Заполняем данные по конкретному человеку. Например:
data = [{
    "age": 22,
    "sex": 1,
    "bmi": 31.350,
    "children": 1,
    "smoker": 0,
    "region_northeast": 0,
    "region_northwest": 1,
    "region_southeast": 0,
    "region_southwest": 0
}]

# %%
df_person = pd.DataFrame(data)
df_person.head()
# Out:
#    age  sex    bmi  children  smoker  region_northeast  region_northwest  \
# 0   22    1  31.35         1       0                 0                 1
#
#    region_southeast  region_southwest
# 0                 0                 0

# %%
# Получаем предсказание по конкретному человеку
lr.predict(df_person)
# Out:
# array([[4060.03059184]])

# %% [markdown]
# ## Проведем сравнение с другими моделями - посмотрим какие модели лучше отработают на данных

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_compare = df.drop("charges", axis=1)
y_compare = df["charges"]

# Делим данные
X_train_compare, X_test_compare, y_train_compare, y_test_compare = train_test_split(X_compare, y_compare, test_size=0.2, random_state=42)

# %%
# Создадим словарь моделей
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(n_estimators=200, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=200, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=200, random_state=42)
}

# %%
# Проведем обучение и оценку
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    results[name] = {"MSE": mse, "RMSE": rmse}

# %%
# Результаты
import pandas as pd
pd.DataFrame(results).T
